# %% [markdown]
# <a href="https://colab.research.google.com/github/kipply/artificial-mickens/blob/master/artificial_mickens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gpt-2-simple
# !pip install tensorflow==1.15.0

# %%
import gpt_2_simple as gpt2
import os
import requests

model_name = "124M"
if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   # /models/124M/

file_name = "mickens.txt"
if not os.path.isfile(file_name):
	print("ohno")
print(file_name)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# mickens.txt

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              model_name=model_name,
              steps=1000)   # steps is max number of training steps
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint checkpoint/run1/model-325
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-325
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  4.13it/s]
# dataset has 22131 tokens
# Training...
# [326 | 8.31] loss=4.66 avg=4.66
# [327 | 9.54] loss=4.14 avg=4.40
# [328 | 10.76] loss=3.80 avg=4.20
# [329 | 12.00] loss=3.84 avg=4.10
# [330 | 13.23] loss=3.53 avg=3.99
# [331 | 14.47] loss=3.52 avg=3.91
# [332 | 15.70] loss=3.51 avg=3.85
# [333 | 16.94] loss=3.43 avg=3.79
# [334 | 18.16] loss=3.43 avg=3.75
# [335 | 19.39] loss=3.35 avg=3.71
# [336 | 20.62] loss=3.39 avg=3.68
# [337 | 21.86] loss=3.23 avg=3.64
# ...

# %%
gpt2.generate(sess)
# Out:
# I am an American and I live in the manner of a Pilgrim who, after a drunken encounter with a bear, discovered that religion is real, and I strongly believe that humanity should stop killing itself and instead allow nature to flourish.
#
# I live under a bridge and I ride on a bike and I don’t tell them where to ride, but I do tell them where to ride.
#
# The last thing that I’ve ever wanted is for people to be constrained by society and assume that I am the Johnny Appleseed of punctuation accuracy.
#
# Thus, I demand that you immediately cease using my online services and, if you believe that humanity has caused all of this, and instead provide free, clear, and unambiguous punctuation for all of your online sentences.
#
# You can test this conjecture by translating the English-only runtime mode into a reliable, non-Ozzy-Ozbourne-inducing five-way tiered syntax, similar to the monocular tiered syntax used by the IFCO and the C++ STL.
#
# ...
